# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
spotify_filepath = "https://storage.googleapis.com/kagglesdsdata/datasets/116573/334386/spotify.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20211230%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211230T120449Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
spotify_data = pd.read_csv(spotify_filepath, index_col = "Date", parse_dates = True)
print("loaded")
# Out:
# loaded

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
sns.lineplot(data = spotify_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (14, 6))
plt.title("Global Popular Songs 2017 - 2018")
sns.lineplot(data = spotify_data)
# Out:
# <AxesSubplot:title={'center':'Global Popular Songs 2017 - 2018'}, xlabel='Date'>

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
plt.figure(figsize = (16, 6))
plt.title("Global Popular Songs 2017 - 2018")
sns.lineplot(data = spotify_data['Shape of You'], label = "Shape of You")
sns.lineplot(data = spotify_data['Something Just Like This'], label = "Something Just Like This")
# Out:
# <AxesSubplot:title={'center':'Global Popular Songs 2017 - 2018'}, xlabel='Date', ylabel='Shape of You'>
