# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
insurance_filepath = "https://storage.googleapis.com/kagglesdsdata/datasets/116573/334386/insurance.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20211230%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211230T195402Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x = insurance_data['bmi'], y = insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize = (14, 8))
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'], hue = insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(data = insurance_data, x = 'bmi', y = 'charges', hue = 'smoker')

# %%
plt.figure(figsize = (14, 26))
sns.swarmplot(x = insurance_data["smoker"], y = insurance_data["charges"])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>
